# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sbr
import pickle as pickle

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
# Out:
# /Users/Vsevolod/anaconda3/envs/DSMLBC_PY36/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
df = pd.read_csv("gpa.csv")
df.columns
df.head()
# Out:
#    high_GPA  univ_GPA
# 0      3.45      3.52
# 1      2.78      2.91
# 2      2.52      2.40
# 3      3.67      3.47
# 4      3.24      3.47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
# high_GPA    105 non-null float64
# univ_GPA    105 non-null float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
    x_columns  = 1
    x = df.iloc[:,0:x_columns].values 
    y = df.iloc[:,x_columns].values

# %%
df = pd.read_csv("GPA.csv", names=['high_GPA', 'univ_GPA'])
df.head()
# Out:
#    high_GPA  univ_GPA
# 0  high_GPA  univ_GPA
# 1      3.45      3.52
# 2      2.78      2.91
# 3      2.52       2.4
# 4      3.67      3.47

# %%
plt.scatter(x, y, marker='o');
plt.xlabel('high_GPA')
plt.ylabel('univ_GPA')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
score = model.score(x_test, y_test)
print(model.score(x_test, y_test))
# Out:
# 0.5726696397623814

# %% [markdown]
# # linear model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

from sklearn.svm import SVR
model2 = SVR(kernel='poly', degree=2, gamma='auto').fit(x_train,y_train)

c
# Out:
# 0.5648059259930291

# %% [markdown]
# # SVR model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)
from sklearn.neighbors import KNeighborsRegressor
model3 = KNeighborsRegressor(n_neighbors=5).fit(x_train, y_train)
y_pred = model3.predict(x_test)
score = model3.score(x_test, y_test)
print(model3.score(x_test, y_test))
# Out:
# 0.16682311735262567

# %% [markdown]
# # KNN model

# %%
colors=['blue', 'purple', 'green']
k=[5,15,30]
scores = []
for i in range(3):
   model3 = KNeighborsRegressor(n_neighbors=k[i]).fit(x_train, y_train)
   plt.plot(x_grid, model3.predict(x_grid), color=colors[i], label=k[i])
   y_pred = model3.predict(x_test)
plt.title('KNN Regression')
plt.legend()
plt.scatter(x, y, color='red')
plt.xlabel('high_GPA')
plt.ylabel('univ_GPA')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y, color='red')
plt.xlabel('high_GPA')
plt.ylabel('univ_GPA')

import numpy as np
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.plot(x_grid, model3.predict(x_grid), color='blue')
plt.title('KNN')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='red')
plt.plot(x, model.predict(x), color='blue')
plt.xlabel('high_GPA')
plt.ylabel('univ_GPA')
plt.title('Simple Linear Regression')

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y, color='red')
plt.xlabel('high_GPA')
plt.ylabel('univ_GPA')

import numpy as np
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.plot(x_grid, model2.predict(x_grid), color='blue')
plt.title('Poly SVR')
plt.show()

# %%
high_school_GPA = 4.0
estimate_university_GPA = model.predict([[high_school_GPA]])
print(estimate_university_GPA)
# Out:
# [3.78478666]

# %%
import pickle
filename = 'GPALinearRegression.sav'
pickle.dump(model, open(filename, 'wb'))
GPA_1 = pickle.load(open(filename, 'rb'))

# %%
new_high_school_GPA = 4.0

new_estimate_university_GPA = GPA_1.predict([[new_high_school_GPA]])
print(new_estimate_university_GPA)
# Out:
# [3.78478666]
