# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sbr
import pickle as pickle

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv('gpa.csv')
print(df.head())

x_columns  = 1
X = df.iloc[:,0:x_columns].values  
y = df.iloc[:,x_columns].values
# Out:
#    high_GPA  univ_GPA
# 0      3.45      3.52
# 1      2.78      2.91
# 2      2.52      2.40
# 3      3.67      3.47
# 4      3.24      3.47

# %%
plt.scatter(X,y)
plt.title('High School GPA to Predict University GPA')
plt.xlabel("High School GPA")
plt.ylabel("University School GPA")
# Out:
# Text(0, 0.5, 'University School GPA')

# %%
#Create a histogram
plt.hist(x)
plt.show()

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score = model.score(x_test, y_test)
print(score)
# Out:
# 0.5726696397623814

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='red')
plt.plot(x, model.predict(x), color='blue')
plt.xlabel('High School GPA')
plt.ylabel('University GPA')
plt.title('Simple Linear Regression')
# Out:
# Text(0.5, 1.0, 'Simple Linear Regression')

# %%
high_school_GPA = 2.6
estimate_university_GPA = model.predict([[high_school_GPA]])
print(estimate_university_GPA)
# Out:
# [2.85016996]

# %%
#save the model to disk
filename = 'GPALinearRegression.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
#Load the model at some point in the future
GPA_1 = pickle.load(open('GPALinearRegression.sav','rb'))

# %%
new_high_school_GPA = 4.0

new_estimate_university_GPA = GPA_1.predict([[new_high_school_GPA]])
print(new_estimate_university_GPA)
# Out:
# [3.78478666]
